# %% [markdown]
# # Overview
#
# **Sections [-@sec-uncertain-decision-problem] and [-@sec-learning-dynamics] define our model.** Section [-@sec-uncertain-decision-problem] contains the implementation of our two decision environments: the single-agent and the two-agent uncertain decision problems. Section [-@sec-learning-dynamics] contains the implementation of the model-based and model-free learning dynamics.
#
# **Sections [-@sec-results-final-rewards] to [-@sec-results-reward-performance-timescales] contain our results.** Section [-@sec-results-final-rewards] shows how we compute the final reward outperformance across different levels of environmental uncertainty. Section [-@sec-results-final-strategies] shows how we visualize the final strategies across different levels of environmental uncertainty. Section[-@#sec-results-strategy-convergence-timescales] shows how we visualize the time steps required to reach the final strategies across different levels of environmental uncertainty. Finally, section [-@sec-results-reward-performance-timescales] compute and visualizes the timescales required to reach almost the rewards of the final strategies across different levels of environmental uncertainty.
#
# **Appendices [-@sec-simulation-scripts] and [-@sec-obtain-noise-variation-data]  contains the code to obtain the simulation data used in our results.** Section [-@sec-simulation-scripts] contains the scripts to run the simulations of our model. Section [-@sec-obtain-noise-variation-data] contains the code to obtain the simulation data used in our results.

# %% [markdown]
# This supplementary information was created in a *fully reproducible writing and computing environment* with the help of [nbdev](https://nbdev.fast.ai) and [quarto](https://quarto.org), version

# %%
# !quarto --version
# Out:
# 1.8.26

# %% [markdown]
# A Python environment with the following packages was used:

# %%
import sys
import importlib.metadata as md

packages = ["numpy", "matplotlib", "pandas", "scipy", "sympy", "scikit-optimize", "jax",
            "nbdev"]
print("Python version:"); print(sys.version); print()
print("Package versions:"); 
for pkg in packages: print(f"{pkg}: {md.version(pkg)}")
# Out:
# Python version:
# 3.14.2 | packaged by Anaconda, Inc. | (main, Dec 19 2025, 11:42:52) [Clang 20.1.8 ]
#
# Package versions:
# numpy: 2.3.5
# matplotlib: 3.10.7
# pandas: 2.3.3
# scipy: 1.16.3
# sympy: 1.14.0
# scikit-optimize: 0.10.2
# jax: 0.8.2
# nbdev: 2.4.7

# %% [markdown]
# The journal template is available from [Quarto Extensions](https://quarto.org/docs/extensions/listing-journals.html). We choose the `arxiv` template from [mikemahoney218](https://github.com/mikemahoney218/quarto-arxiv), which must be installed into an existing Quarto project via
# ```
# quarto add mikemahoney218/quarto-arxiv
# ```
# to be able to render the main manuscript file in the arXiv format via
#
# ```
# quarto render Article.ipynb
# ```

# %% [markdown]
# Finally, the supplementary information document is compiled as a Quarto book project and configured in the `_quarto.yml` file. To make the PDF output visually pleasing, Quarto's Code Visibility Extension is used to hide some code lines that only serve PDF astetics. The extension must be installed via
# ```
# quarto install extension jjallaire/code-visibility
# ```
# to be able to render the supplementary information to PDF via
# ```
# quarto render .
# ```
